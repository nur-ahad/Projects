# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('bank_dataset.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]>

# %%
df.head(20)
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# 12   36     technician  married   tertiary      no     1109      no   no
# 13   20        student   single  secondary      no      502      no   no
# 14   31    blue-collar  married  secondary      no      360     yes  yes
# 15   40     management  married   tertiary      no      194      no  yes
# 16   56     technician  married  secondary      no     4073      no   no
# 17   37         admin.   single   tertiary      no     2317     yes   no
# 18   25    blue-collar   single    primary      no     -221     yes   no
# 19   31       services  married  secondary      no      132      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome    y
# 0   cellular   19   oct        79         1     -1         0  unknown   no
# 1   cellular   11   may       220         1    339         4  failure   no
# 2   cellular   16   apr       185         1    330         1  failure   no
# 3    unknown    3   jun       199         4     -1         0  unknown   no
# 4    unknown    5   may       226         1     -1         0  unknown   no
# 5   cellular   23   feb       141         2    176         3  failure   no
# 6   cellular   14   may       341         1    330         2    other   no
# 7   cellular    6   may       151         2     -1         0  unknown   no
# 8    unknown   14   may        57         2     -1         0  unknown   no
# 9   cellular   17   apr       313         1    147         2  failure   no
# 10   unknown   20   may       273         1     -1         0  unknown   no
# 11  cellular   17   apr       113         2     -1         0  unknown   no
# 12  cellular   13   aug       328         2     -1         0  unknown   no
# 13  cellular   30   apr       261         1     -1         0  unknown  yes
# 14  cellular   29   jan        89         1    241         1  failure   no
# 15  cellular   29   aug       189         2     -1         0  unknown   no
# 16  cellular   27   aug       239         5     -1         0  unknown   no
# 17  cellular   20   apr       114         1    152         2  failure   no
# 18   unknown   23   may       250         1     -1         0  unknown   no
# 19  cellular    7   jul       148         1    152         1    other   no

# %%
df.tail(20)
# Out:
#       age            job   marital  education default  balance housing loan  \
# 4501   34     management   married   tertiary      no      297     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4503   60  self-employed   married    primary      no      362      no  yes
# 4504   42    blue-collar    single  secondary      no     1080     yes  yes
# 4505   32         admin.    single  secondary      no      620     yes   no
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4507   33       services   married  secondary      no      288     yes   no
# 4508   42         admin.   married    unknown      no      642     yes  yes
# 4509   51     technician   married   tertiary      no     2506      no   no
# 4510   36     technician  divorced  secondary      no      566     yes   no
# 4511   46    blue-collar   married  secondary      no      668     yes   no
# 4512   40    blue-collar   married  secondary      no     1100     yes   no
# 4513   49    blue-collar   married  secondary      no      322      no   no
# 4514   38    blue-collar   married  secondary      no     1205     yes   no
# 4515   32       services    single  secondary      no      473     yes   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 4518   57     technician   married  secondary      no      295      no   no
# 4519   28    blue-collar   married  secondary      no     1137      no   no
# 4520   44   entrepreneur    single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 4501  cellular   26   aug        63         4     -1         0  unknown   no
# 4502  cellular    5   feb        43         1     -1         0  unknown   no
# 4503  cellular   29   jul       816         6     -1         0  unknown  yes
# 4504  cellular   13   may       951         3    370         4  failure  yes
# 4505   unknown   26   may      1234         3     -1         0  unknown  yes
# 4506  cellular   29   aug        85         4     -1         0  unknown   no
# 4507  cellular   17   apr       306         1     -1         0  unknown   no
# 4508   unknown   16   may       509         2     -1         0  unknown   no
# 4509  cellular   30   nov       210         3     -1         0  unknown   no
# 4510   unknown   20   may       129         2     -1         0  unknown   no
# 4511   unknown   15   may      1263         2     -1         0  unknown  yes
# 4512   unknown   29   may       660         2     -1         0  unknown   no
# 4513  cellular   14   aug       356         2     -1         0  unknown   no
# 4514  cellular   20   apr        45         4    153         1  failure   no
# 4515  cellular    7   jul       624         5     -1         0  unknown   no
# 4516  cellular   30   jul       329         5     -1         0  unknown   no
# 4517   unknown    9   may       153         1     -1         0  unknown   no
# 4518  cellular   19   aug       151        11     -1         0  unknown   no
# 4519  cellular    6   feb       129         4    211         3    other   no
# 4520  cellular    3   apr       345         2    249         7    other   no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
df['job'].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
df['marital'].value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
df['education'].value_counts()
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
df['default'].value_counts()
# Out:
# no     4445
# yes      76
# Name: default, dtype: int64

# %%
df['housing'].value_counts()
# Out:
# yes    2559
# no     1962
# Name: housing, dtype: int64

# %%
df['loan'].value_counts()
# Out:
# no     3830
# yes     691
# Name: loan, dtype: int64

# %%
df['contact'].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
df['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
df['poutcome'].value_counts()
# Out:
# unknown    3705
# failure     490
# other       197
# success     129
# Name: poutcome, dtype: int64

# %%
sns.histplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['balance'])
# Out:
# <AxesSubplot:xlabel='balance', ylabel='Count'>

# %%
sns.histplot(df['duration'])
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Count'>

# %%
sns.histplot(df['campaign'])
# Out:
# <AxesSubplot:xlabel='campaign', ylabel='Count'>

# %%
sns.histplot(df['pdays'])
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='Count'>

# %%
sns.histplot(df['previous'])
# Out:
# <AxesSubplot:xlabel='previous', ylabel='Count'>

# %%
cat_vars = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']
df_encoded = pd.get_dummies(df, columns=cat_vars, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X = df_encoded.drop('y', axis=1)
y = df_encoded['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(solver='lbfgs')
lr.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
y_pred = lr.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, pos_label='yes'))
print("Recall:", recall_score(y_test, y_pred, pos_label='yes'))
print("F1 score:", f1_score(y_test, y_pred,pos_label='yes'))
# Out:
# Accuracy: 0.8916728076639646
# Precision: 0.5342465753424658
# Recall: 0.2565789473684211
# F1 score: 0.3466666666666667
# C:\Users\nural\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
coefs = pd.DataFrame({'variable': X_train.columns, 'coefficient': lr.coef_[0]})
coefs = coefs.sort_values(by='coefficient', ascending=False)
print(coefs)
# Out:
#                variable  coefficient
# 40     poutcome_success     0.333210
# 11          job_retired     0.234007
# 37            month_oct     0.169797
# 34            month_mar     0.106479
# 26    contact_telephone     0.090137
# 21   education_tertiary     0.072855
# 38            month_sep     0.055508
# 10       job_management     0.043797
# 28            month_aug     0.030925
# 29            month_dec     0.021957
# 17          job_unknown     0.019686
# 14          job_student     0.013944
# 9         job_housemaid     0.013855
# 23          default_yes     0.007223
# 3              duration     0.004313
# 39       poutcome_other     0.004151
# 5                 pdays     0.002656
# 1               balance     0.000010
# 31            month_jan    -0.002084
# 2                   day    -0.005550
# 12    job_self-employed    -0.014984
# 30            month_feb    -0.017458
# 22    education_unknown    -0.033491
# 0                   age    -0.037150
# 33            month_jun    -0.046706
# 4              campaign    -0.054608
# 16       job_unemployed    -0.055251
# 36            month_nov    -0.071162
# 8      job_entrepreneur    -0.074294
# 15       job_technician    -0.100499
# 32            month_jul    -0.101874
# 6              previous    -0.120219
# 13         job_services    -0.130315
# 18      marital_married    -0.223841
# 19       marital_single    -0.226571
# 25             loan_yes    -0.248420
# 7       job_blue-collar    -0.335148
# 20  education_secondary    -0.357680
# 27      contact_unknown    -0.536764
# 41     poutcome_unknown    -0.557103
# 35            month_may    -0.601661
# 24          housing_yes    -0.722649
